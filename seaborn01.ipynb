# %% [markdown]
# <a href="https://colab.research.google.com/github/JakubDemeszko/ML_Course/blob/main/seaborn01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 20, 100)
y = np.random.randn(100, 4)
y = np.cumsum(y, axis = 0)

# %%
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7978bb1ecf10>,
#  <matplotlib.lines.Line2D at 0x7978bb1ec3d0>,
#  <matplotlib.lines.Line2D at 0x7978bb1ec460>,
#  <matplotlib.lines.Line2D at 0x7978bb1eeb90>]

# %%
# Creating a basing chart with using random generated data and seaborn library
sns.set()
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7978babc4070>,
#  <matplotlib.lines.Line2D at 0x7978babc42e0>,
#  <matplotlib.lines.Line2D at 0x7978babc4370>,
#  <matplotlib.lines.Line2D at 0x7978babc7700>]

# %%
# Loading data from Seaborn
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Checking the basic info about DF.
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Looking for the relation between 2 columns
sns.relplot(data = df, x = 'total_bill', y = 'tip')

# %%
# Changing the style of the Chart
sns.set(palette = 'pastel', font_scale = 1)
sns.relplot(data = df, x = 'total_bill', y = 'tip')

# %%
# Checking the same data groupped by the particular column, changing the size
sns.relplot(data = df, x = 'total_bill', y = 'tip', hue = 'sex', size = 'sex')

# %%
# Making the same chart with the split by particular col
sns.relplot(data = df, x = 'total_bill', y = 'tip', hue = 'sex', size = 'sex',
            col = 'time')

# %%
# Making the field of charts with base on particular cols, rows
sns.relplot(data = df, x = 'total_bill', y = 'tip', hue = 'sex', size = 'sex',
            col = 'time', row = 'smoker')
